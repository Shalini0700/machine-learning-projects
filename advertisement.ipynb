# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
adv = pd.read_csv(r"C:\Users\karta\AppData\Local\Microsoft\Windows\INetCache\IE\NRPQW76P\advertising[1].csv")
adv
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
adv.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
adv.tail()
# Out:
#         TV  Radio  Newspaper  Sales
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4

# %%
#data cleaning
adv.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
adv.dtypes
# Out:
# TV           float64
# Radio        float64
# Newspaper    float64
# Sales        float64
# dtype: object

# %%
adv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
adv.TV.unique()
# Out:
# array([230.1,  44.5,  17.2, 151.5, 180.8,   8.7,  57.5, 120.2,   8.6,
#        199.8,  66.1, 214.7,  23.8,  97.5, 204.1, 195.4,  67.8, 281.4,
#         69.2, 147.3, 218.4, 237.4,  13.2, 228.3,  62.3, 262.9, 142.9,
#        240.1, 248.8,  70.6, 292.9, 112.9,  97.2, 265.6,  95.7, 290.7,
#        266.9,  74.7,  43.1, 228. , 202.5, 177. , 293.6, 206.9,  25.1,
#        175.1,  89.7, 239.9, 227.2,  66.9, 100.4, 216.4, 182.6, 262.7,
#        198.9,   7.3, 136.2, 210.8, 210.7,  53.5, 261.3, 239.3, 102.7,
#        131.1,  69. ,  31.5, 139.3, 216.8, 199.1, 109.8,  26.8, 129.4,
#        213.4,  16.9,  27.5, 120.5,   5.4, 116. ,  76.4, 239.8,  75.3,
#         68.4, 213.5, 193.2,  76.3, 110.7,  88.3, 134.3,  28.6, 217.7,
#        250.9, 107.4, 163.3, 197.6, 184.9, 289.7, 135.2, 222.4, 296.4,
#        280.2, 187.9, 238.2, 137.9,  25. ,  90.4,  13.1, 255.4, 225.8,
#        241.7, 175.7, 209.6,  78.2,  75.1, 139.2, 125.7,  19.4, 141.3,
# ...

# %%
adv.Radio.unique()
# Out:
# array([37.8, 39.3, 45.9, 41.3, 10.8, 48.9, 32.8, 19.6,  2.1,  2.6,  5.8,
#        24. , 35.1,  7.6, 32.9, 47.7, 36.6, 39.6, 20.5, 23.9, 27.7,  5.1,
#        15.9, 16.9, 12.6,  3.5, 29.3, 16.7, 27.1, 16. , 28.3, 17.4,  1.5,
#        20. ,  1.4,  4.1, 43.8, 49.4, 26.7, 37.7, 22.3, 33.4,  8.4, 25.7,
#        22.5,  9.9, 41.5, 15.8, 11.7,  3.1,  9.6, 41.7, 46.2, 28.8, 28.1,
#        19.2, 49.6, 29.5,  2. , 42.7, 15.5, 29.6, 42.8,  9.3, 24.6, 14.5,
#        27.5, 43.9, 30.6, 14.3, 33. ,  5.7, 43.7,  1.6, 28.5, 29.9,  7.7,
#        20.3, 44.5, 43. , 18.4, 40.6, 25.5, 47.8,  4.9, 33.5, 36.5, 14. ,
#        31.6, 21. , 42.3,  4.3, 36.3, 10.1, 17.2, 34.3, 46.4, 11. ,  0.3,
#         0.4, 26.9,  8.2, 38. , 15.4, 20.6, 46.8, 35. ,  0.8, 36.9, 26.8,
#        21.7,  2.4, 34.6, 32.3, 11.8, 38.9,  0. , 49. , 12. ,  2.9, 27.2,
#        38.6, 47. , 39. , 28.9, 25.9, 17. , 35.4, 33.2, 14.8,  1.9,  7.3,
#        40.3, 25.8, 13.9, 23.3, 39.7, 21.1, 11.6, 43.5,  1.3, 18.1, 35.8,
# ...

# %%
adv.Newspaper.unique()
# Out:
# array([ 69.2,  45.1,  69.3,  58.5,  58.4,  75. ,  23.5,  11.6,   1. ,
#         21.2,  24.2,   4. ,  65.9,   7.2,  46. ,  52.9, 114. ,  55.8,
#         18.3,  19.1,  53.4,  49.6,  26.2,  19.5,  12.6,  22.9,  40.8,
#         43.2,  38.6,  30. ,   0.3,   7.4,   8.5,   5. ,  45.7,  35.1,
#         32. ,  31.6,  38.7,   1.8,  26.4,  43.3,  31.5,  35.7,  18.5,
#         49.9,  36.8,  34.6,   3.6,  39.6,  58.7,  15.9,  60. ,  41.4,
#         16.6,  37.7,   9.3,  21.4,  54.7,  27.3,   8.4,  28.9,   0.9,
#          2.2,  10.2,  11. ,  27.2,  31.7,  19.3,  31.3,  13.1,  89.4,
#         20.7,  14.2,   9.4,  23.1,  22.3,  36.9,  32.5,  35.6,  33.8,
#         65.7,  16. ,  63.2,  73.4,  51.4,  33. ,  59. ,  72.3,  10.9,
#          5.9,  22. ,  51.2,  45.9,  49.8, 100.9,  17.9,   5.3,  29.7,
#         23.2,  25.6,   5.5,  56.5,   2.4,  10.7,  34.5,  52.7,  14.8,
#         79.2,  46.2,  50.4,  15.6,  12.4,  74.2,  25.9,  50.6,   9.2,
# ...

# %%
adv.Sales.unique()
# Out:
# array([22.1, 10.4, 12. , 16.5, 17.9,  7.2, 11.8, 13.2,  4.8, 15.6, 12.6,
#        17.4,  9.2, 13.7, 19. , 22.4, 12.5, 24.4, 11.3, 14.6, 18. , 17.5,
#         5.6, 20.5,  9.7, 17. , 15. , 20.9, 18.9, 10.5, 21.4, 11.9, 17.8,
#        25.4, 14.7, 10.1, 21.5, 16.6, 17.1, 20.7,  8.5, 16.1, 10.6, 23.2,
#        19.8, 16.4, 10.7, 22.6, 21.2, 20.2, 23.7,  5.5, 23.8, 18.4,  8.1,
#        24.2, 14. , 16. , 11. , 13.4, 22.3, 18.3, 12.4,  8.8,  8.7,  6.9,
#        14.2,  5.3, 17.3, 13.6, 21.7, 12.9, 16.7,  7.3, 19.4, 22.2, 11.5,
#        16.9, 17.2, 19.7, 21.8, 12.2,  9.4, 15.9,  6.6, 15.5,  7. , 15.2,
#        24.7,  1.6, 17.7,  5.7, 19.6, 10.8, 11.6,  9.5, 20.8,  9.6, 10.9,
#        19.2, 20.1, 12.3, 10.3, 18.2, 20.6,  3.2, 15.3, 13.3, 19.9,  8. ,
#        20. ,  8.4,  7.6, 27. , 16.8, 17.6, 26.2,  6.7,  5.9, 14.8, 25.5])

# %%
for i in adv.columns:
    print(i,':','\n',adv[i].unique(),'\n')
# Out:
# TV :
#  [230.1  44.5  17.2 151.5 180.8   8.7  57.5 120.2   8.6 199.8  66.1 214.7
#   23.8  97.5 204.1 195.4  67.8 281.4  69.2 147.3 218.4 237.4  13.2 228.3
#   62.3 262.9 142.9 240.1 248.8  70.6 292.9 112.9  97.2 265.6  95.7 290.7
#  266.9  74.7  43.1 228.  202.5 177.  293.6 206.9  25.1 175.1  89.7 239.9
#  227.2  66.9 100.4 216.4 182.6 262.7 198.9   7.3 136.2 210.8 210.7  53.5
#  261.3 239.3 102.7 131.1  69.   31.5 139.3 216.8 199.1 109.8  26.8 129.4
#  213.4  16.9  27.5 120.5   5.4 116.   76.4 239.8  75.3  68.4 213.5 193.2
#   76.3 110.7  88.3 134.3  28.6 217.7 250.9 107.4 163.3 197.6 184.9 289.7
#  135.2 222.4 296.4 280.2 187.9 238.2 137.9  25.   90.4  13.1 255.4 225.8
#  241.7 175.7 209.6  78.2  75.1 139.2 125.7  19.4 141.3  18.8 224.  123.1
#  229.5  87.2   7.8  80.2 220.3  59.6   0.7 265.2   8.4 219.8  36.9  48.3
#   25.6 273.7  43.   73.4 193.7 220.5 104.6  96.2 140.3 243.2  38.   44.7
#  280.7 121.  171.3 187.8   4.1  93.9 149.8  11.7 131.7 172.5  85.7 188.4
# ...

# %%
adv.describe(include='all')
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#Data Analysis
sns.scatterplot(x=adv.Newspaper,y=adv.Sales)
plt.show()

# %%
for i in ['TV','Radio','Newspaper']:
    sns.scatterplot(x=adv[i],y=adv.Sales)
    plt.show()

# %%
sns.histplot(data=adv)
plt.show()

# %%
sns.kdeplot(data=adv,fill=True)
plt.show()

# %%
sns.jointplot(data=adv)
plt.show()

# %%
sns.pairplot(data=adv,hue='Sales')
plt.show()

# %%
for i in ['TV','Radio','Newspaper']:
    sns.boxplot(x=adv[i],y=adv.Sales)
    plt.show()

# %%
for i in ['TV','Radio','Newspaper']:
    sns.violinplot(x=adv[i],y=adv.Sales)
    plt.show()

# %%
for i in ['TV','Radio','Newspaper']:
    sns.swarmplot(x=adv[i],y=adv.Sales)
    plt.show()

# %%
for i in ['TV','Radio','Newspaper']:
    sns.stripplot(x=adv[i],y=adv.Sales)
    plt.show()

# %%
sns.scatterplot(x=adv.TV,y=adv.Radio,hue=adv.Sales)
plt.show()

# %%
for i in ['TV','Radio','Newspaper']:
    sns.barplot(x=adv[i],y=adv.Sales)
    plt.show()

# %%
for i in ['TV','Radio','Newspaper']:
    sns.pointplot(x=adv[i],y=adv.Sales)
    plt.show()

# %%
#heat map
c=adv.corr()
c
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.901208
# Radio      0.054809  1.000000   0.354104  0.349631
# Newspaper  0.056648  0.354104   1.000000  0.157960
# Sales      0.901208  0.349631   0.157960  1.000000

# %%
sns.heatmap(c , annot=True)
plt.show()

# %%
#ip/op creation
ip=adv.drop('Sales',axis=1)
op=adv.Sales

# %%
ip.head()
# Out:
#       TV  Radio  Newspaper
# 0  230.1   37.8       69.2
# 1   44.5   39.3       45.1
# 2   17.2   45.9       69.3
# 3  151.5   41.3       58.5
# 4  180.8   10.8       58.4

# %%
#train test split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(ip,op,test_size=0.2,random_state=30)

# %%
x_train
# Out:
#         TV  Radio  Newspaper
# 125   87.2   11.8       25.9
# 60    53.5    2.0       21.4
# 90   134.3    4.9        9.3
# 152  197.6   23.3       14.2
# 40   202.5   22.3       31.6
# ..     ...    ...        ...
# 140   73.4   17.0       12.9
# 45   175.1   22.5       31.5
# 173  168.4    7.1       12.8
# 165  234.5    3.4       84.8
# 37    74.7   49.4       45.7
#
# [160 rows x 3 columns]

# %%
x_test
# Out:
#         TV  Radio  Newspaper
# 143  104.6    5.7       34.4
# 81   239.8    4.1       36.9
# 26   142.9   29.3       12.6
# 150  280.7   13.9       37.0
# 124  229.5   32.3       74.2
# 24    62.3   12.6       18.3
# 126    7.8   38.9       50.6
# 142  220.5   33.2       37.9
# 129   59.6   12.0       43.1
# 171  164.5   20.9       47.4
# 72    26.8   33.0       19.3
# 97   184.9   21.0       22.0
# 21   237.4    5.1       23.5
# 67   139.3   14.5       10.2
# 106   25.0   11.0       29.7
# 184  253.8   21.3       30.0
# 111  241.7   38.0       23.2
# 63   102.7   29.6        8.4
# 93   250.9   36.5       72.3
# 183  287.6   43.0       71.8
# 86    76.3   27.5       16.0
# 158   11.7   36.9       45.2
# 133  219.8   33.5       45.1
# 50   199.8    3.1       34.6
# 99   135.2   41.7       45.9
# 199  232.1    8.6        8.7
# 189   18.7   12.1       23.4
# 101  296.4   36.3      100.9
# 100  222.4    4.3       49.8
# 103  187.9   17.2       17.9
# 139  184.9   43.9        1.7
# ...

# %%
y_train
# Out:
# 125    10.6
# 60      8.1
# 90     14.0
# 152    16.6
# 40     16.6
#        ...
# 140    10.9
# 45     16.1
# 173    16.7
# 165    16.9
# 37     14.7
# Name: Sales, Length: 160, dtype: float64

# %%
y_test
# Out:
# 143    10.4
# 81     17.3
# 26     15.0
# 150    16.1
# 124    19.7
# 24      9.7
# 126     6.6
# 142    20.1
# 129     9.7
# 171    17.5
# 72      8.8
# 97     20.5
# 21     17.5
# 67     13.4
# 106     7.2
# 184    17.6
# 111    21.8
# 63     14.0
# 93     22.2
# 183    26.2
# 86     12.0
# 158     7.3
# 133    19.6
# 50     16.4
# 99     17.2
# 199    18.4
# 189     6.7
# 101    23.8
# 100    16.7
# 103    19.7
# 139    20.7
# 57     13.2
# 36     25.4
# 114    14.6
# 54     20.2
# 25     17.0
# 1      10.4
# 149    10.1
# 193    19.6
# 121     7.0
# Name: Sales, dtype: float64

# %%
#standard scaler transform
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.fit_transform(x_test)

# %%
x_train
# Out:
# array([[-6.79251307e-01, -7.33930202e-01, -1.90350451e-01],
#        [-1.08052255e+00, -1.38303763e+00, -3.96878970e-01],
#        [-1.18424135e-01, -1.19095482e+00, -9.52211209e-01],
#        [ 6.35299008e-01,  2.77774926e-02, -7.27324600e-01],
#        [ 6.93644085e-01, -3.84579591e-02,  7.12523389e-02],
#        [ 1.63311890e+00,  1.10741536e+00,  1.18191682e+00],
#        [ 1.02228166e+00,  9.88191542e-01,  1.79691285e+00],
#        [-1.48417523e+00, -1.84175953e-01, -5.98817966e-01],
#        [ 7.23411982e-01,  1.47171034e+00, -4.79490377e-01],
#        [-1.43416517e+00,  8.09355823e-01,  1.64545860e+00],
#        [-3.99433079e-01,  1.17365081e+00,  1.52154149e+00],
#        [ 8.63789941e-02,  1.22001562e+00,  1.30583393e+00],
#        [ 1.17826544e+00,  1.73002860e+00,  6.54121714e-01],
#        [-1.24722278e+00,  1.20676853e+00, -1.11284450e+00],
#        [ 7.91282786e-01,  4.38437293e-01, -9.52211209e-01],
#        [ 8.74632897e-01,  7.03379100e-01,  1.32878154e+00],
# ...

# %%
x_test
# Out:
# array([[-0.58861656, -1.41586641,  0.0852711 ],
#        [ 0.89527229, -1.53448854,  0.20240174],
#        [-0.16825456,  0.33381011, -0.93610805],
#        [ 1.34417062, -0.80792796,  0.20708697],
#        [ 0.78222454,  0.55622661,  1.94999085],
#        [-1.0528806 , -0.90430844, -0.6690502 ],
#        [-1.65104586,  1.04554292,  0.84427763],
#        [ 0.68344496,  0.62295156,  0.249254  ],
#        [-1.08251448, -0.94879174,  0.49288572],
#        [ 0.06881644, -0.28895611,  0.69435042],
#        [-1.44251118,  0.6081238 , -0.62219794],
#        [ 0.29271683, -0.28154223, -0.49569686],
#        [ 0.86893107, -1.46034971, -0.42541847],
#        [-0.20776639, -0.76344466, -1.04855346],
#        [-1.4622671 , -1.02293058, -0.13493449],
#        [ 1.04892942, -0.25930058, -0.12087882],
#        [ 0.91612576,  0.97881797, -0.43947415],
#        [-0.60947003,  0.35605176, -1.13288752],
#        [ 1.01710044,  0.86760972,  1.86097156],
#        [ 1.41990163,  1.34951215,  1.83754543],
# ...

# %%
#ML Model
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_test
# Out:
# 143    10.4
# 81     17.3
# 26     15.0
# 150    16.1
# 124    19.7
# 24      9.7
# 126     6.6
# 142    20.1
# 129     9.7
# 171    17.5
# 72      8.8
# 97     20.5
# 21     17.5
# 67     13.4
# 106     7.2
# 184    17.6
# 111    21.8
# 63     14.0
# 93     22.2
# 183    26.2
# 86     12.0
# 158     7.3
# 133    19.6
# 50     16.4
# 99     17.2
# 199    18.4
# 189     6.7
# 101    23.8
# 100    16.7
# 103    19.7
# 139    20.7
# 57     13.2
# 36     25.4
# 114    14.6
# 54     20.2
# 25     17.0
# 1      10.4
# 149    10.1
# 193    19.6
# 121     7.0
# Name: Sales, dtype: float64

# %%
pred=lr.predict(x_test)
pred
# Out:
# array([10.14412273, 16.8148058 , 14.603849  , 19.98544291, 19.68950425,
#         8.68481698,  9.08109158, 19.11775803,  8.6297173 , 14.96014656,
#         9.19025937, 15.85031115, 16.7254804 , 12.74293881,  6.68745131,
#        19.41561615, 20.64119617, 12.57988918, 21.23242131, 23.8159713 ,
#        11.05457354,  9.02092255, 19.15933218, 14.66615969, 15.80903378,
#        16.76229144,  6.45481682, 23.68208026, 16.03501355, 15.55000571,
#        18.3038955 , 13.1532155 , 22.4583243 , 13.43228546, 20.62443355,
#        17.81078368, 10.94858452,  9.2933248 , 17.1864946 ,  7.7016383 ])

# %%
#accuracy
from sklearn.metrics import mean_squared_error,r2_score
mse=mean_squared_error(pred,y_test)
r2=r2_score(pred,y_test)

print('mean_squared_error: ',mse)
print('r2_score: ',r2)
# Out:
# mean_squared_error:  3.0230639777988357
# r2_score:  0.8703865275819311

# %%
df=pd.DataFrame({'Y_test':list(y_test),'Prediction':pred})
df
# Out:
#     Y_test  Prediction
# 0     10.4   10.144123
# 1     17.3   16.814806
# 2     15.0   14.603849
# 3     16.1   19.985443
# 4     19.7   19.689504
# 5      9.7    8.684817
# 6      6.6    9.081092
# 7     20.1   19.117758
# 8      9.7    8.629717
# 9     17.5   14.960147
# 10     8.8    9.190259
# 11    20.5   15.850311
# 12    17.5   16.725480
# 13    13.4   12.742939
# 14     7.2    6.687451
# 15    17.6   19.415616
# 16    21.8   20.641196
# 17    14.0   12.579889
# 18    22.2   21.232421
# 19    26.2   23.815971
# 20    12.0   11.054574
# 21     7.3    9.020923
# 22    19.6   19.159332
# 23    16.4   14.666160
# 24    17.2   15.809034
# 25    18.4   16.762291
# 26     6.7    6.454817
# 27    23.8   23.682080
# 28    16.7   16.035014
# 29    19.7   15.550006
# 30    20.7   18.303896
# 31    13.2   13.153216
# 32    25.4   22.458324
# 33    14.6   13.432285
# 34    20.2   20.624434
# 35    17.0   17.810784
# 36    10.4   10.948585
# 37    10.1    9.293325
# 38    19.6   17.186495
# ...

# %%
sns.lmplot(x='Y_test',y='Prediction',data=df)
plt.show()
